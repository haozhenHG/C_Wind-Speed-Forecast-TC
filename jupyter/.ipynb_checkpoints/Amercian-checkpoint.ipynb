# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../datas/American_datas.csv',index_col='date')
data
# Out:
#             load  temp1  temp2  temp3  weekday  season
# date
# 2015/7/2   77437   68.0   63.9   69.9        4       2
# 2015/7/2   72863   68.0   63.9   69.9        4       2
# 2015/7/2   69862   68.0   63.9   69.9        4       2
# 2015/7/2   67951   68.0   63.9   69.9        4       2
# 2015/7/2   67153   68.0   63.9   69.9        4       2
# ...          ...    ...    ...    ...      ...     ...
# 2022/3/13  75756   51.0   39.1   47.8        7       1
# 2022/3/13  76606   51.0   39.1   47.8        7       1
# 2022/3/13  75081   51.0   39.1   47.8        7       1
# 2022/3/13  72716   51.0   39.1   47.8        7       1
# 2022/3/13  72716   51.0   39.1   47.8        7       1
#
# [58728 rows x 6 columns]

# %%
data.columns,data.shape
# Out:
# (Index(['load', 'temp1', 'temp2', 'temp3', 'weekday', 'season'], dtype='object'),
#  (58728, 6))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58728 entries, 2015/7/2 to 2022/3/13
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   load     58728 non-null  int64
#  1   temp1    58728 non-null  float64
#  2   temp2    58728 non-null  float64
#  3   temp3    58728 non-null  float64
#  4   weekday  58728 non-null  int64
#  5   season   58728 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 3.1+ MB

# %%
data.index
# Out:
# Index(['2015/7/2', '2015/7/2', '2015/7/2', '2015/7/2', '2015/7/2', '2015/7/2',
#        '2015/7/2', '2015/7/2', '2015/7/2', '2015/7/2',
#        ...
#        '2022/3/13', '2022/3/13', '2022/3/13', '2022/3/13', '2022/3/13',
#        '2022/3/13', '2022/3/13', '2022/3/13', '2022/3/13', '2022/3/13'],
#       dtype='object', name='date', length=58728)

# %%
data.index = pd.to_datetime(data.index)
data.index
# Out:
# DatetimeIndex(['2015-07-02', '2015-07-02', '2015-07-02', '2015-07-02',
#                '2015-07-02', '2015-07-02', '2015-07-02', '2015-07-02',
#                '2015-07-02', '2015-07-02',
#                ...
#                '2022-03-13', '2022-03-13', '2022-03-13', '2022-03-13',
#                '2022-03-13', '2022-03-13', '2022-03-13', '2022-03-13',
#                '2022-03-13', '2022-03-13'],
#               dtype='datetime64[ns]', name='date', length=58728, freq=None)

# %%
# 绘制图表
plt.figure(figsize=(13,3))
plt.plot(data.index, data.load,label='American Load')

# 添加标题和轴标签
plt.title('American Load')
plt.xlabel('Date [24 per day]')
plt.ylabel('Load')

plt.legend(loc='upper right')
# 显示图表
plt.show()

# %%
# 检查采样频率
print(f"采样间隔: {pd.infer_freq(data.index)}")  # 应显示'H'（每小时一次）
# Out:
# 采样间隔: None

# %%
data['dayofy'] = data.index.day_of_year
data.sample(10)
# Out:
#               load  temp1  temp2  temp3  weekday  season  dayofy
# date
# 2016-02-11   88174   21.0   16.6   22.2        4       4      42
# 2020-12-21   80333   37.5   36.4   38.5        1       4     356
# 2021-04-03   63953   60.9   52.4   57.0        6       1      93
# 2016-09-30   76485   62.1   59.4   57.6        5       3     274
# 2018-11-06   75893   38.5   40.5   44.2        2       3     310
# 2018-02-28   64809   39.5   36.2   51.1        3       4      59
# 2017-09-24  103232   81.1   75.3   77.1        7       3     267
# 2021-12-18   80241   34.8   28.4   33.6        6       4     352
# 2018-04-26   73625   51.9   49.0   55.9        4       1     116
# 2018-12-17   88181   30.5   28.6   32.9        1       4     351

# %%
data.describe()
# Out:
#                 load         temp1         temp2         temp3       weekday  \
# count   58728.000000  58728.000000  58728.000000  58728.000000  58728.000000
# mean    80600.955762     52.991881     50.063803     54.440999      4.002452
# std     12879.265500     19.762357     19.114753     18.759176      1.999811
# min     52782.000000    -13.500000     -8.200000     -4.200000      1.000000
# 25%     71443.000000     37.000000     34.500000     38.700000      2.000000
# 50%     78666.500000     52.300000     50.200000     55.400000      4.000000
# 75%     87433.000000     71.300000     67.500000     71.900000      6.000000
# max    130257.000000     87.300000     85.200000     84.700000      7.000000
#
#              season        dayofy
# count  58728.000000  58728.000000
# mean       2.545975    185.644463
# std        1.107361    106.905457
# min        1.000000      1.000000
# 25%        2.000000     90.000000
# 50%        3.000000    191.000000
# 75%        4.000000    278.000000
# max        4.000000    366.000000

# %%
data
# Out:
#                       load  temp1  temp2  temp3  weekday  season  dayofy
# 2015-07-02 00:00:00  77437   68.0   63.9   69.9        4       2     183
# 2015-07-02 01:00:00  72863   68.0   63.9   69.9        4       2     183
# 2015-07-02 02:00:00  69862   68.0   63.9   69.9        4       2     183
# 2015-07-02 03:00:00  67951   68.0   63.9   69.9        4       2     183
# 2015-07-02 04:00:00  67153   68.0   63.9   69.9        4       2     183
# ...                    ...    ...    ...    ...      ...     ...     ...
# 2022-03-13 19:00:00  75756   51.0   39.1   47.8        7       1      72
# 2022-03-13 20:00:00  76606   51.0   39.1   47.8        7       1      72
# 2022-03-13 21:00:00  75081   51.0   39.1   47.8        7       1      72
# 2022-03-13 22:00:00  72716   51.0   39.1   47.8        7       1      72
# 2022-03-13 23:00:00  72716   51.0   39.1   47.8        7       1      72
#
# [58728 rows x 7 columns]

# %%
data.to_csv('American_index_H.csv')

# %% [markdown]
# ## 分析缺失值和异常值

# %%
# 检查缺失值
data.isnull().sum() # 了解每个特征中缺失值的具体数量时使用
# Out:
# load       0
# temp1      0
# temp2      0
# temp3      0
# weekday    0
# season     0
# dayofy     0
# dtype: int64

# %%
data.isnull().any()  # 判断只需要判断数据集中是否存在缺失值
# Out:
# load       False
# temp1      False
# temp2      False
# temp3      False
# weekday    False
# season     False
# dayofy     False
# dtype: bool

# %% [markdown]
# ### 结论：没有缺失值

# %%
# 绘制箱线图
plt.figure(figsize=(6, 4))
sns.boxplot(data.load)
plt.title("Boxplot of Time Series Data")
plt.show()

# %%
# 绘制箱线图
melted_df = data.melt(value_vars=['temp1', 'temp2', 'temp3'], var_name='Temperature Sensor', value_name='Temperature')

# 绘制箱线图
plt.figure(figsize=(8, 6))
sns.boxplot(x='Temperature Sensor', y='Temperature', data=melted_df)
plt.title("Boxplot of Temperature Data")
plt.xlabel("Temperature Sensor")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# - 根据箱线图 查看存在异常值的特征列数据
# - 实际上只有负载这一列存在异常值

# %%
data.columns
# Out:
# Index(['load', 'temp1', 'temp2', 'temp3', 'weekday', 'season', 'dayofy'], dtype='object')

# %%
Q1 = data['load'].quantile(0.25) # quantile用于计算数据的分位数
Q3 = data['load'].quantile(0.75)
IQR = Q3 - Q1  # IQR 两个四分位值的跨度

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("异常值：")
data[(data['load'] < lower_bound) | (data['load'] > upper_bound)]
# Out:
# 异常值：
#                        load  temp1  temp2  temp3  weekday  season  dayofy
# 2015-07-06 15:00:00  111839   69.0   72.9   74.8        1       2     187
# 2015-07-06 16:00:00  112499   69.0   72.9   74.8        1       2     187
# 2015-07-06 17:00:00  112783   69.0   72.9   74.8        1       2     187
# 2015-07-06 18:00:00  111767   69.0   72.9   74.8        1       2     187
# 2015-07-12 17:00:00  112870   78.0   72.1   74.2        7       2     193
# ...                     ...    ...    ...    ...      ...     ...     ...
# 2021-08-28 14:00:00  111487   82.7   76.8   81.0        6       2     240
# 2021-08-28 15:00:00  113175   82.7   76.8   81.0        6       2     240
# 2021-08-28 16:00:00  114313   82.7   76.8   81.0        6       2     240
# 2021-08-28 17:00:00  114295   82.7   76.8   81.0        6       2     240
# 2021-08-28 18:00:00  113132   82.7   76.8   81.0        6       2     240
#
# [1593 rows x 7 columns]

# %%
data.loc['2015-07-06 00:00:00':'2015-07-06 23:00:00',:]
# Out:
#                        load  temp1  temp2  temp3  weekday  season  dayofy
# 2015-07-06 00:00:00   78546   69.0   72.9   74.8        1       2     187
# 2015-07-06 01:00:00   73890   69.0   72.9   74.8        1       2     187
# 2015-07-06 02:00:00   70589   69.0   72.9   74.8        1       2     187
# 2015-07-06 03:00:00   68627   69.0   72.9   74.8        1       2     187
# 2015-07-06 04:00:00   68070   69.0   72.9   74.8        1       2     187
# 2015-07-06 05:00:00   69453   69.0   72.9   74.8        1       2     187
# 2015-07-06 06:00:00   72763   69.0   72.9   74.8        1       2     187
# 2015-07-06 07:00:00   77737   69.0   72.9   74.8        1       2     187
# 2015-07-06 08:00:00   83383   69.0   72.9   74.8        1       2     187
# 2015-07-06 09:00:00   88690   69.0   72.9   74.8        1       2     187
# 2015-07-06 10:00:00   93981   69.0   72.9   74.8        1       2     187
# 2015-07-06 11:00:00   99120   69.0   72.9   74.8        1       2     187
# 2015-07-06 12:00:00  103833   69.0   72.9   74.8        1       2     187
# 2015-07-06 13:00:00  107512   69.0   72.9   74.8        1       2     187
# 2015-07-06 14:00:00  110262   69.0   72.9   74.8        1       2     187
# 2015-07-06 15:00:00  111839   69.0   72.9   74.8        1       2     187
# 2015-07-06 16:00:00  112499   69.0   72.9   74.8        1       2     187
# 2015-07-06 17:00:00  112783   69.0   72.9   74.8        1       2     187
# 2015-07-06 18:00:00  111767   69.0   72.9   74.8        1       2     187
# 2015-07-06 19:00:00  109311   69.0   72.9   74.8        1       2     187
# 2015-07-06 20:00:00  105673   69.0   72.9   74.8        1       2     187
# 2015-07-06 21:00:00  103647   69.0   72.9   74.8        1       2     187
# 2015-07-06 22:00:00  100323   69.0   72.9   74.8        1       2     187
# 2015-07-06 23:00:00   93076   69.0   72.9   74.8        1       2     187

# %%
data.shape
# Out:
# (58728, 7)

# %% [markdown]
# ### 结论 ：异常值就1593条   下一步纠正异常值

# %%
datac = data.copy()  # 创作副本datac  不影响源数据data
datac.shape
# Out:
# (58728, 7)

# %%
datac.head(10)
# Out:
#                       load  temp1  temp2  temp3  weekday  season  dayofy
# 2015-07-02 00:00:00  77437   68.0   63.9   69.9        4       2     183
# 2015-07-02 01:00:00  72863   68.0   63.9   69.9        4       2     183
# 2015-07-02 02:00:00  69862   68.0   63.9   69.9        4       2     183
# 2015-07-02 03:00:00  67951   68.0   63.9   69.9        4       2     183
# 2015-07-02 04:00:00  67153   68.0   63.9   69.9        4       2     183
# 2015-07-02 05:00:00  68405   68.0   63.9   69.9        4       2     183
# 2015-07-02 06:00:00  71204   68.0   63.9   69.9        4       2     183
# 2015-07-02 07:00:00  75033   68.0   63.9   69.9        4       2     183
# 2015-07-02 08:00:00  78999   68.0   63.9   69.9        4       2     183
# 2015-07-02 09:00:00  82401   68.0   63.9   69.9        4       2     183

# %%
outliers = (datac['load'] < lower_bound) | (datac['load'] > upper_bound)
datac[outliers] = np.nan
datac = datac.interpolate()

# 绘制箱线图
plt.figure(figsize=(6, 4))
sns.boxplot(datac.load)
plt.title("Boxplot of Time Series Data")
plt.show()

# %%
Q1 = datac['load'].quantile(0.25) # quantile用于计算数据的分位数
Q3 = datac['load'].quantile(0.75)
IQR = Q3 - Q1  # IQR 两个四分位值的跨度

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("异常值：")
datac[(datac['load'] < lower_bound) | (datac['load'] > upper_bound)]
# Out:
# 异常值：
#                               load  temp1  temp2  temp3  weekday  season  \
# 2015-07-06 14:00:00  110262.000000   69.0   72.9   74.8      1.0     2.0
# 2015-07-06 15:00:00  110071.800000   69.0   72.9   74.8      1.0     2.0
# 2015-07-06 16:00:00  109881.600000   69.0   72.9   74.8      1.0     2.0
# 2015-07-06 17:00:00  109691.400000   69.0   72.9   74.8      1.0     2.0
# 2015-07-06 18:00:00  109501.200000   69.0   72.9   74.8      1.0     2.0
# ...                            ...    ...    ...    ...      ...     ...
# 2021-08-27 18:00:00  110640.142857   84.2   79.6   78.8      5.0     2.0
# 2021-08-27 19:00:00  111136.000000   84.2   79.6   78.8      5.0     2.0
# 2021-08-28 17:00:00  109530.666667   82.7   76.8   81.0      6.0     2.0
# 2021-08-28 18:00:00  109826.833333   82.7   76.8   81.0      6.0     2.0
# 2021-08-28 19:00:00  110123.000000   82.7   76.8   81.0      6.0     2.0
#
#                      dayofy
# 2015-07-06 14:00:00   187.0
# 2015-07-06 15:00:00   187.0
# 2015-07-06 16:00:00   187.0
# 2015-07-06 17:00:00   187.0
# 2015-07-06 18:00:00   187.0
# ...                     ...
# 2021-08-27 18:00:00   239.0
# 2021-08-27 19:00:00   239.0
# 2021-08-28 17:00:00   240.0
# 2021-08-28 18:00:00   240.0
# 2021-08-28 19:00:00   240.0
#
# [1271 rows x 7 columns]

# %% [markdown]
# 经过线性修正的数据异常值减少了  由原来的 1593 rows × 7 columns  --->   1271 rows × 7 columns

# %%
datac.to_csv('American_H_fix.csv')

# %% [markdown]
# ## 二、深度特征工程

# %%
datac.head()
# Out:
#                         load  temp1  temp2  temp3  weekday  season  dayofy
# 2015-07-02 00:00:00  77437.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 01:00:00  72863.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 02:00:00  69862.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 03:00:00  67951.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 04:00:00  67153.0   68.0   63.9   69.9      4.0     2.0   183.0

# %%
# 周期性编码
datac['week_sin'] = np.sin(2*np.pi*datac['weekday']/7)
datac['week_cos'] = np.cos(2*np.pi*datac['weekday']/7)

# 时间上下文特征
datac['hour'] = datac.index.hour
datac['is_working_hour'] = ((datac['hour']>=8) & (datac['hour']<=18)).astype(int)

# %%
datac.head(24)
# Out:
#                         load  temp1  temp2  temp3  weekday  season  dayofy  \
# 2015-07-02 00:00:00  77437.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 01:00:00  72863.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 02:00:00  69862.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 03:00:00  67951.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 04:00:00  67153.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 05:00:00  68405.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 06:00:00  71204.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 07:00:00  75033.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 08:00:00  78999.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 09:00:00  82401.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 10:00:00  85489.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 11:00:00  88452.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 12:00:00  90991.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 13:00:00  93456.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 14:00:00  95601.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 15:00:00  97046.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 16:00:00  97627.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 17:00:00  97675.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 18:00:00  96420.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 19:00:00  93971.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 20:00:00  91118.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 21:00:00  89650.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 22:00:00  87493.0   68.0   63.9   69.9      4.0     2.0   183.0
# 2015-07-02 23:00:00  81759.0   68.0   63.9   69.9      4.0     2.0   183.0
#
#                      week_sin  week_cos  hour  is_working_hour
# 2015-07-02 00:00:00 -0.433884 -0.900969     0                0
# 2015-07-02 01:00:00 -0.433884 -0.900969     1                0
# 2015-07-02 02:00:00 -0.433884 -0.900969     2                0
# 2015-07-02 03:00:00 -0.433884 -0.900969     3                0
# 2015-07-02 04:00:00 -0.433884 -0.900969     4                0
# 2015-07-02 05:00:00 -0.433884 -0.900969     5                0
# 2015-07-02 06:00:00 -0.433884 -0.900969     6                0
# 2015-07-02 07:00:00 -0.433884 -0.900969     7                0
# 2015-07-02 08:00:00 -0.433884 -0.900969     8                1
# 2015-07-02 09:00:00 -0.433884 -0.900969     9                1
# 2015-07-02 10:00:00 -0.433884 -0.900969    10                1
# 2015-07-02 11:00:00 -0.433884 -0.900969    11                1
# 2015-07-02 12:00:00 -0.433884 -0.900969    12                1
# 2015-07-02 13:00:00 -0.433884 -0.900969    13                1
# 2015-07-02 14:00:00 -0.433884 -0.900969    14                1
# 2015-07-02 15:00:00 -0.433884 -0.900969    15                1
# 2015-07-02 16:00:00 -0.433884 -0.900969    16                1
# 2015-07-02 17:00:00 -0.433884 -0.900969    17                1
# 2015-07-02 18:00:00 -0.433884 -0.900969    18                1
# 2015-07-02 19:00:00 -0.433884 -0.900969    19                0
# 2015-07-02 20:00:00 -0.433884 -0.900969    20                0
# 2015-07-02 21:00:00 -0.433884 -0.900969    21                0
# 2015-07-02 22:00:00 -0.433884 -0.900969    22                0
# 2015-07-02 23:00:00 -0.433884 -0.900969    23                0

# %%
datac[['temp1','temp2',	'temp3']].describe()
# Out:
#               temp1         temp2         temp3
# count  58728.000000  58728.000000  58728.000000
# mean      52.991881     50.063803     54.440999
# std       19.762357     19.114753     18.759176
# min      -13.500000     -8.200000     -4.200000
# 25%       37.000000     34.500000     38.700000
# 50%       52.300000     50.200000     55.400000
# 75%       71.300000     67.500000     71.900000
# max       87.300000     85.200000     84.700000

# %%
# 绘制折线图
plt.figure(figsize=(13, 3))
for col in ['temp1', 'temp2', 'temp3']:
    plt.plot(datac.index, datac[col], label=col)

# 添加标题和标签
plt.title('Temperature Variation Over Time')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
# plt.grid(True)

# 显示图形
plt.show()

# %%
temp_cols = ['temp1', 'temp2', 'temp3']
datac['temp_gradient'] = datac[temp_cols].diff(axis=1).mean(axis=1)  # 时间梯度

# %%
# 构建热力学特征
datac['heat_index'] = 0.5 * (datac['temp2'] + 0.1 * datac['temp2'] * datac['temp1'])

# %%
# 负载相关
# 滞后特征
datac['load_lag24'] = datac['load'].shift(24)  # 昨日同期负载

# 滚动统计量
# 计算过去 1 到 7 天的滚动  均值 标准差
for days in range(1, 8):
    window_size = 24 * days
    datac[f'load_roll_mean_{days}d'] = datac['load'].rolling(window_size).mean()    
    datac[f'load_roll_std_{days}d'] = datac['load'].rolling(window_size).std()

# %%
datac.to_csv('American_new.csv')

# %%
datac.shape
# Out:
# (58728, 28)

# %%
datac.isnull().sum()
# Out:
# load                   0
# temp1                  0
# temp2                  0
# temp3                  0
# weekday                0
# season                 0
# dayofy                 0
# week_sin               0
# week_cos               0
# hour                   0
# is_working_hour        0
# heat_index             0
# temp_gradient          0
# load_lag24            24
# load_roll_mean_1d     23
# load_roll_std_1d      23
# load_roll_mean_2d     47
# load_roll_std_2d      47
# load_roll_mean_3d     71
# load_roll_std_3d      71
# load_roll_mean_4d     95
# load_roll_std_4d      95
# load_roll_mean_5d    119
# load_roll_std_5d     119
# load_roll_mean_6d    143
# load_roll_std_6d     143
# load_roll_mean_7d    167
# load_roll_std_7d     167
# dtype: int64

# %% [markdown]
# 由于构造了滞后特征相关的信息    导致原始数据出现不争气的情况   -- 直接删除  原始数据集的影响小

# %%
datacc = datac.copy()

# %%
datacc.dropna(inplace=True)
datacc.head()
# Out:
#                         load  temp1  temp2  temp3  weekday  season  dayofy  \
# 2015-07-08 23:00:00  83755.0   66.3   66.6   69.4      3.0     2.0   189.0
# 2015-07-09 00:00:00  78238.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 01:00:00  73926.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 02:00:00  71250.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 03:00:00  69507.0   71.5   68.9   68.0      4.0     2.0   190.0
#
#                      week_sin  week_cos  hour  ...  load_roll_mean_3d  \
# 2015-07-08 23:00:00  0.433884 -0.900969    23  ...       88803.888889
# 2015-07-09 00:00:00 -0.433884 -0.900969     0  ...       88799.611111
# 2015-07-09 01:00:00 -0.433884 -0.900969     1  ...       88800.111111
# 2015-07-09 02:00:00 -0.433884 -0.900969     2  ...       88809.291667
# 2015-07-09 03:00:00 -0.433884 -0.900969     3  ...       88821.513889
#
#                      load_roll_std_3d  load_roll_mean_4d  load_roll_std_4d  \
# 2015-07-08 23:00:00      12477.558615       86736.375000      13356.203696
# 2015-07-09 00:00:00      12481.177211       86785.739583      13315.458833
# 2015-07-09 01:00:00      12480.572221       86835.770833      13257.290906
# 2015-07-09 02:00:00      12467.223650       86893.750000      13175.732692
# 2015-07-09 03:00:00      12447.575173       86957.291667      13075.601056
#
#                      load_roll_mean_5d  load_roll_std_5d  load_roll_mean_6d  \
# 2015-07-08 23:00:00       84688.458333      13424.628653       83796.076389
# 2015-07-09 00:00:00       84724.775000      13401.017538       83815.027778
# 2015-07-09 01:00:00       84764.408333      13361.602856       83835.847222
# 2015-07-09 02:00:00       84808.916667      13307.050752       83859.604167
# 2015-07-09 03:00:00       84856.916667      13240.662544       83885.826389
#
#                      load_roll_std_6d  load_roll_mean_7d  load_roll_std_7d
# 2015-07-08 23:00:00      13059.823927       83837.446429      12716.644903
# 2015-07-09 00:00:00      13049.690403       83842.214286      12714.380769
# 2015-07-09 01:00:00      13031.365328       83848.541667      12709.147612
# 2015-07-09 02:00:00      13005.071655       83856.803571      12700.449036
# 2015-07-09 03:00:00      12972.028011       83866.065476      12689.342649
#
# [5 rows x 28 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import lightgbm as lgb

def get_feature_importances(data, shuffle, seed=None):
    # 剔除 Unnamed: 0 列
    features = [i for i in data.columns if i not in ['load']]
    y = data['load'].copy()
    x = data[features]

    if shuffle:
        # Here you could as well use a binomial distribution
        y = data['load'].copy().sample(frac=1.0)

    xtrain, xval, ytrain, yval = train_test_split(x, y, random_state=42, test_size=0.25)
    model = lgb.LGBMRegressor(
        num_leaves=32,
        max_depth=7,
        learning_rate=0.08,
        n_estimators=1000,
        importance_type='split',
        subsample=0.8,
        feature_fraction=0.8,
        reg_alpha=0.5,
        reg_lambda=0.5,
        random_state=2021,
        objective='regression',
        metric='mse',
        device='cpu'  # 修改为使用 CPU 进行计算
    )

    # Fit the model
    model = model.fit(
        xtrain,
        ytrain,
        eval_metric="mse",
        eval_set=[(xval, yval)]
    )

    # Get feature importances
    imp_df = pd.DataFrame()
    imp_df["feature"] = list(features)
    imp_df["importance_split"] = model.feature_importances_

    return imp_df

# 调用函数获取特征重要性
result = get_feature_importances(datacc, shuffle=False)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5400
# [LightGBM] [Info] Number of data points in the train set: 43920, number of used features: 27
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Start training from score 80043.014721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# 按照重要性降序排序
result = result.sort_values(by='importance_split', ascending=False).reset_index(drop=True)

print('特征重要性：')
result
# Out:
# 特征重要性：
#               feature  importance_split
# 0                hour              2740
# 1   load_roll_mean_1d              2301
# 2          load_lag24              1999
# 3    load_roll_std_1d              1941
# 4               temp3              1689
# 5              dayofy              1625
# 6       temp_gradient              1529
# 7               temp2              1445
# 8   load_roll_mean_2d              1379
# 9               temp1              1324
# 10   load_roll_std_2d              1131
# 11         heat_index              1065
# 12  load_roll_mean_3d              1029
# 13            weekday               996
# 14   load_roll_std_7d               986
# 15  load_roll_mean_7d               912
# 16  load_roll_mean_4d               865
# 17   load_roll_std_3d               842
# 18  load_roll_mean_5d               834
# 19   load_roll_std_6d               827
# 20  load_roll_mean_6d               823
# 21   load_roll_std_4d               799
# 22   load_roll_std_5d               754
# 23           week_sin               513
# 24           week_cos               318
# 25    is_working_hour               178
# 26             season               122

# %%
# 设置负号显示
plt.rcParams['axes.unicode_minus'] = False
# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
# 创建柱状图
plt.figure(figsize=(8,5))
sns.barplot(x='importance_split', y='feature', data=result)

# # 添加数据标签
# for i, v in enumerate(result['importance_split']):
#     plt.text(v + 3, i + 0.25, str(v), color='black')

# 添加标题和标签
plt.title('特征重要性可视化')
plt.xlabel('特征重要性得分')
plt.ylabel('特征名称')

# 显示图形
plt.show()

# %% [markdown]
# 通过上述信息 并结合实际情况
# ```
# 1. 核心影响特征
# hour（小时）：重要性得分最高，说明一天内的不同小时对目标变量（如负载）影响显著，反映出时间周期性规律（如早晚高峰用电差异）对结果的强关联性。
# 负载相关衍生特征：
# load_roll_mean_1d（1 天滚动均值）、load_lag24（24 小时滞后负载）、load_roll_std_1d（1 天滚动标准差）等特征重要性靠前，表明历史负载数据的均值、滞后值、波动情况对当前目标变量有较强预测能力，体现了负载数据的时序依赖性。
# 2. 环境与时间特征
# 温度相关特征：temp1、temp2、temp3及temp_gradient（温度梯度）重要性中等，说明温度及其变化趋势对目标变量存在影响，可能反映温度与负载（如空调使用导致的用电变化）的关联。
# ```

# %%
features = result.loc[:9].feature.tolist() + ['load']
datacc[features]
# Out:
#                      hour  load_roll_mean_1d  load_lag24  load_roll_std_1d  \
# 2015-07-08 23:00:00    23       84724.916667     83322.0      10392.528281
# 2015-07-09 00:00:00     0       84769.375000     77171.0      10361.042854
# 2015-07-09 01:00:00     1       84811.083333     72925.0      10313.194630
# 2015-07-09 02:00:00     2       84853.708333     70227.0      10252.230953
# 2015-07-09 03:00:00     3       84897.833333     68448.0      10180.580344
# ...                   ...                ...         ...               ...
# 2022-03-13 19:00:00    19       78716.125000     86743.0       5201.702934
# 2022-03-13 20:00:00    20       78249.250000     87811.0       4840.193809
# 2022-03-13 21:00:00    21       77748.333333     87103.0       4493.758228
# 2022-03-13 22:00:00    22       77220.208333     85391.0       4297.010538
# 2022-03-13 23:00:00    23       76790.791667     83022.0       4206.002067
#
#                      temp3  dayofy  temp_gradient  temp2  load_roll_mean_2d  \
# 2015-07-08 23:00:00   69.4   189.0           1.55   66.6       87005.166667
# 2015-07-09 00:00:00   68.0   190.0          -1.75   68.9       86842.750000
# 2015-07-09 01:00:00   68.0   190.0          -1.75   68.9       86699.041667
# 2015-07-09 02:00:00   68.0   190.0          -1.75   68.9       86573.875000
# 2015-07-09 03:00:00   68.0   190.0          -1.75   68.9       86458.666667
# ...                    ...     ...            ...    ...                ...
# 2022-03-13 19:00:00   47.8    72.0          -1.60   39.1       82081.292155
# 2022-03-13 20:00:00   47.8    72.0          -1.60   39.1       81830.854655
# 2022-03-13 21:00:00   47.8    72.0          -1.60   39.1       81537.501139
# 2022-03-13 22:00:00   47.8    72.0          -1.60   39.1       81162.707520
# 2022-03-13 23:00:00   47.8    72.0          -1.60   39.1       80816.708333
#
#                      temp1     load
# 2015-07-08 23:00:00   66.3  83755.0
# 2015-07-09 00:00:00   71.5  78238.0
# 2015-07-09 01:00:00   71.5  73926.0
# 2015-07-09 02:00:00   71.5  71250.0
# 2015-07-09 03:00:00   71.5  69507.0
# ...                    ...      ...
# 2022-03-13 19:00:00   51.0  75756.0
# 2022-03-13 20:00:00   51.0  76606.0
# 2022-03-13 21:00:00   51.0  75081.0
# 2022-03-13 22:00:00   51.0  72716.0
# 2022-03-13 23:00:00   51.0  72716.0
#
# [58561 rows x 11 columns]

# %%
datacc.to_csv('American_final.csv')

# %%
df = pd.read_csv('./American_final.csv',index_col='Unnamed: 0')
df.head()
# Out:
#                         load  temp1  temp2  temp3  weekday  season  dayofy  \
# 2015-07-08 23:00:00  83755.0   66.3   66.6   69.4      3.0     2.0   189.0
# 2015-07-09 00:00:00  78238.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 01:00:00  73926.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 02:00:00  71250.0   71.5   68.9   68.0      4.0     2.0   190.0
# 2015-07-09 03:00:00  69507.0   71.5   68.9   68.0      4.0     2.0   190.0
#
#                      week_sin  week_cos  hour  ...  load_roll_mean_3d  \
# 2015-07-08 23:00:00  0.433884 -0.900969    23  ...       88803.888889
# 2015-07-09 00:00:00 -0.433884 -0.900969     0  ...       88799.611111
# 2015-07-09 01:00:00 -0.433884 -0.900969     1  ...       88800.111111
# 2015-07-09 02:00:00 -0.433884 -0.900969     2  ...       88809.291667
# 2015-07-09 03:00:00 -0.433884 -0.900969     3  ...       88821.513889
#
#                      load_roll_std_3d  load_roll_mean_4d  load_roll_std_4d  \
# 2015-07-08 23:00:00      12477.558615       86736.375000      13356.203696
# 2015-07-09 00:00:00      12481.177211       86785.739583      13315.458833
# 2015-07-09 01:00:00      12480.572221       86835.770833      13257.290906
# 2015-07-09 02:00:00      12467.223650       86893.750000      13175.732692
# 2015-07-09 03:00:00      12447.575173       86957.291667      13075.601056
#
#                      load_roll_mean_5d  load_roll_std_5d  load_roll_mean_6d  \
# 2015-07-08 23:00:00       84688.458333      13424.628653       83796.076389
# 2015-07-09 00:00:00       84724.775000      13401.017538       83815.027778
# 2015-07-09 01:00:00       84764.408333      13361.602856       83835.847222
# 2015-07-09 02:00:00       84808.916667      13307.050752       83859.604167
# 2015-07-09 03:00:00       84856.916667      13240.662544       83885.826389
#
#                      load_roll_std_6d  load_roll_mean_7d  load_roll_std_7d
# 2015-07-08 23:00:00      13059.823927       83837.446429      12716.644903
# 2015-07-09 00:00:00      13049.690403       83842.214286      12714.380769
# 2015-07-09 01:00:00      13031.365328       83848.541667      12709.147612
# 2015-07-09 02:00:00      13005.071655       83856.803571      12700.449036
# 2015-07-09 03:00:00      12972.028011       83866.065476      12689.342649
#
# [5 rows x 28 columns]

# %% [markdown]
# 0	hour	2740
# 1	load_roll_mean_1d	2301
# 2	load_lag24	1999
# 3	load_roll_std_1d	1941
# 4	temp3	1689
# 5	dayofy	1625
# 6	temp_gradient	1529
# 7	temp2	1445
# 8	load_roll_mean_2d	1379
# 9	temp1	1324
# 9	temp1	1324

# %%
dat = df[['hour','load_roll_mean_1d','load_lag24','load_roll_std_1d','temp3','dayofy','temp_gradient','temp2','load_roll_mean_2d','temp1','load']]
dat.head()
# Out:
#                      hour  load_roll_mean_1d  load_lag24  load_roll_std_1d  \
# 2015-07-08 23:00:00    23       84724.916667     83322.0      10392.528281
# 2015-07-09 00:00:00     0       84769.375000     77171.0      10361.042854
# 2015-07-09 01:00:00     1       84811.083333     72925.0      10313.194630
# 2015-07-09 02:00:00     2       84853.708333     70227.0      10252.230953
# 2015-07-09 03:00:00     3       84897.833333     68448.0      10180.580344
#
#                      temp3  dayofy  temp_gradient  temp2  load_roll_mean_2d  \
# 2015-07-08 23:00:00   69.4   189.0           1.55   66.6       87005.166667
# 2015-07-09 00:00:00   68.0   190.0          -1.75   68.9       86842.750000
# 2015-07-09 01:00:00   68.0   190.0          -1.75   68.9       86699.041667
# 2015-07-09 02:00:00   68.0   190.0          -1.75   68.9       86573.875000
# 2015-07-09 03:00:00   68.0   190.0          -1.75   68.9       86458.666667
#
#                      temp1     load
# 2015-07-08 23:00:00   66.3  83755.0
# 2015-07-09 00:00:00   71.5  78238.0
# 2015-07-09 01:00:00   71.5  73926.0
# 2015-07-09 02:00:00   71.5  71250.0
# 2015-07-09 03:00:00   71.5  69507.0

# %%
dat.to_csv('American_final.csv',index=True)

# %% [markdown]
# ## 数据太多 截取部分数据进行训练即可

# %%
dff = pd.read_csv('./American_final.csv',index_col=0) # 列 0 作为时间索引戳
dff.head()
# Out:
#                      hour  load_roll_mean_1d  load_lag24  load_roll_std_1d  \
# 2015-07-08 23:00:00    23       84724.916667     83322.0      10392.528281
# 2015-07-09 00:00:00     0       84769.375000     77171.0      10361.042854
# 2015-07-09 01:00:00     1       84811.083333     72925.0      10313.194630
# 2015-07-09 02:00:00     2       84853.708333     70227.0      10252.230953
# 2015-07-09 03:00:00     3       84897.833333     68448.0      10180.580344
#
#                      temp3  dayofy  temp_gradient  temp2  load_roll_mean_2d  \
# 2015-07-08 23:00:00   69.4   189.0           1.55   66.6       87005.166667
# 2015-07-09 00:00:00   68.0   190.0          -1.75   68.9       86842.750000
# 2015-07-09 01:00:00   68.0   190.0          -1.75   68.9       86699.041667
# 2015-07-09 02:00:00   68.0   190.0          -1.75   68.9       86573.875000
# 2015-07-09 03:00:00   68.0   190.0          -1.75   68.9       86458.666667
#
#                      temp1     load
# 2015-07-08 23:00:00   66.3  83755.0
# 2015-07-09 00:00:00   71.5  78238.0
# 2015-07-09 01:00:00   71.5  73926.0
# 2015-07-09 02:00:00   71.5  71250.0
# 2015-07-09 03:00:00   71.5  69507.0

# %%
dff.index.min(),dff.index.max()
# Out:
# ('2015-07-08 23:00:00', '2022-03-13 23:00:00')

# %%
dff[:'2021-12-31 23:00:00']
# Out:
#                      hour  load_roll_mean_1d  load_lag24  load_roll_std_1d  \
# 2015-07-08 23:00:00    23       84724.916667     83322.0      10392.528281
# 2015-07-09 00:00:00     0       84769.375000     77171.0      10361.042854
# 2015-07-09 01:00:00     1       84811.083333     72925.0      10313.194630
# 2015-07-09 02:00:00     2       84853.708333     70227.0      10252.230953
# 2015-07-09 03:00:00     3       84897.833333     68448.0      10180.580344
# ...                   ...                ...         ...               ...
# 2021-12-31 19:00:00    19       74446.833333     83445.0       4178.295582
# 2021-12-31 20:00:00    20       74252.500000     81524.0       3936.276413
# 2021-12-31 21:00:00    21       74049.291667     79554.0       3773.197854
# 2021-12-31 22:00:00    22       73862.958333     77140.0       3724.033069
# 2021-12-31 23:00:00    23       73727.833333     74153.0       3771.583345
#
#                      temp3  dayofy  temp_gradient  temp2  load_roll_mean_2d  \
# 2015-07-08 23:00:00   69.4   189.0           1.55   66.6       87005.166667
# 2015-07-09 00:00:00   68.0   190.0          -1.75   68.9       86842.750000
# 2015-07-09 01:00:00   68.0   190.0          -1.75   68.9       86699.041667
# 2015-07-09 02:00:00   68.0   190.0          -1.75   68.9       86573.875000
# 2015-07-09 03:00:00   68.0   190.0          -1.75   68.9       86458.666667
# ...                    ...     ...            ...    ...                ...
# 2021-12-31 19:00:00   51.9   365.0           6.25   33.5       76551.354167
# 2021-12-31 20:00:00   51.9   365.0           6.25   33.5       76382.312500
# 2021-12-31 21:00:00   51.9   365.0           6.25   33.5       76206.916667
# 2021-12-31 22:00:00   51.9   365.0           6.25   33.5       76042.770833
# 2021-12-31 23:00:00   32.9   365.0           2.70   20.2       75908.000000
#
#                      temp1     load
# 2015-07-08 23:00:00   66.3  83755.0
# 2015-07-09 00:00:00   71.5  78238.0
# 2015-07-09 01:00:00   71.5  73926.0
# 2015-07-09 02:00:00   71.5  71250.0
# 2015-07-09 03:00:00   71.5  69507.0
# ...                    ...      ...
# 2021-12-31 19:00:00   39.4  79055.0
# 2021-12-31 20:00:00   39.4  76860.0
# 2021-12-31 21:00:00   39.4  74677.0
# 2021-12-31 22:00:00   39.4  72668.0
# 2021-12-31 23:00:00   27.5  70910.0
#
# [56833 rows x 11 columns]

# %%
dff['2021-01-01 00:00:00':'2021-12-31 23:00:00']
# Out:
#                      hour  load_roll_mean_1d  load_lag24  load_roll_std_1d  \
# 2021-01-01 00:00:00     0       78302.750000     74068.0       4778.815682
# 2021-01-01 01:00:00     1       78333.083333     72444.0       4742.180685
# 2021-01-01 02:00:00     2       78370.000000     71316.0       4688.322227
# 2021-01-01 03:00:00     3       78402.666667     70369.0       4632.549675
# 2021-01-01 04:00:00     4       78416.583333     70013.0       4606.679884
# ...                   ...                ...         ...               ...
# 2021-12-31 19:00:00    19       74446.833333     83445.0       4178.295582
# 2021-12-31 20:00:00    20       74252.500000     81524.0       3936.276413
# 2021-12-31 21:00:00    21       74049.291667     79554.0       3773.197854
# 2021-12-31 22:00:00    22       73862.958333     77140.0       3724.033069
# 2021-12-31 23:00:00    23       73727.833333     74153.0       3771.583345
#
#                      temp3  dayofy  temp_gradient  temp2  load_roll_mean_2d  \
# 2021-01-01 00:00:00   35.5     1.0           0.95   33.7       78159.500000
# 2021-01-01 01:00:00   35.5     1.0           0.95   33.7       78188.854167
# 2021-01-01 02:00:00   35.5     1.0           0.95   33.7       78221.583333
# 2021-01-01 03:00:00   35.5     1.0           0.95   33.7       78252.312500
# 2021-01-01 04:00:00   35.5     1.0           0.95   33.7       78274.062500
# ...                    ...     ...            ...    ...                ...
# 2021-12-31 19:00:00   51.9   365.0           6.25   33.5       76551.354167
# 2021-12-31 20:00:00   51.9   365.0           6.25   33.5       76382.312500
# 2021-12-31 21:00:00   51.9   365.0           6.25   33.5       76206.916667
# 2021-12-31 22:00:00   51.9   365.0           6.25   33.5       76042.770833
# 2021-12-31 23:00:00   32.9   365.0           2.70   20.2       75908.000000
#
#                      temp1     load
# 2021-01-01 00:00:00   33.6  74565.0
# 2021-01-01 01:00:00   33.6  73172.0
# 2021-01-01 02:00:00   33.6  72202.0
# 2021-01-01 03:00:00   33.6  71153.0
# 2021-01-01 04:00:00   33.6  70347.0
# ...                    ...      ...
# 2021-12-31 19:00:00   39.4  79055.0
# 2021-12-31 20:00:00   39.4  76860.0
# 2021-12-31 21:00:00   39.4  74677.0
# 2021-12-31 22:00:00   39.4  72668.0
# 2021-12-31 23:00:00   27.5  70910.0
#
# [8760 rows x 11 columns]

# %%
dff[:'2017-12-31 23:00:00'].to_csv('American_final_to_model.csv',index=True)

# %%
dff['load'].values.shape
# Out:
# (58561,)
